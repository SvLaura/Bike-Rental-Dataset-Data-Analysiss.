# %% [markdown]
# # Get Data

# %%
import pandas as pd
import data_func

df = data_func.data_to_df()
df.head(2)
# Out:
# ------>end download data
#   duration_sec                start_time                  end_time  \
# 0        80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1        78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
#
#   start_station_id                                 start_station_name  \
# 0               74                              Laguna St at Hayes St
# 1              284  Yerba Buena Center for the Arts (Howard St at ...
#
#   start_station_latitude start_station_longitude end_station_id  \
# 0          37.7764348192         -122.4262440205             43
# 1          37.7848720844         -122.4008756876             96
#
#                                     end_station_name end_station_latitude  \
# 0  San Francisco Public Library (Grove St at Hyde...           37.7787677
# 1                              Dolores St at 15th St           37.7662102
#
#    ... rental_access_method ride_id rideable_type started_at ended_at  \
# 0  ...                  NaN     NaN           NaN        NaN      NaN
# 1  ...                  NaN     NaN           NaN        NaN      NaN
#
#   start_lat start_lng end_lat end_lng member_casual
# 0       NaN       NaN     NaN     NaN           NaN
# 1       NaN       NaN     NaN     NaN           NaN
#
# [2 rows x 26 columns]

# %% [markdown]
# # Explore Data

# %%
df.head(3)
# Out:
#   duration_sec                start_time                  end_time  \
# 0        80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1        78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
# 2        45768  2017-12-31 22:45:48.4110  2018-01-01 11:28:36.8830
#
#   start_station_id                                 start_station_name  \
# 0               74                              Laguna St at Hayes St
# 1              284  Yerba Buena Center for the Arts (Howard St at ...
# 2              245                             Downtown Berkeley BART
#
#   start_station_latitude start_station_longitude end_station_id  \
# 0          37.7764348192         -122.4262440205             43
# 1          37.7848720844         -122.4008756876             96
# 2             37.8703477            -122.2677637            245
#
#                                     end_station_name end_station_latitude  \
# 0  San Francisco Public Library (Grove St at Hyde...           37.7787677
# 1                              Dolores St at 15th St           37.7662102
# 2                             Downtown Berkeley BART           37.8703477
#
#   end_station_longitude bike_id user_type member_birth_year member_gender  \
# 0          -122.4159292      96  Customer               NaN           NaN
# 1          -122.4266136      88  Customer               NaN           NaN
# 2          -122.2677637    1094  Customer               NaN           NaN
#
#   bike_share_for_all_trip
# 0                     NaN
# 1                     NaN
# 2                     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9071194 entries, 0 to 2035162
# Data columns (total 26 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   duration_sec             object
#  1   start_time               object
#  2   end_time                 object
#  3   start_station_id         object
#  4   start_station_name       object
#  5   start_station_latitude   object
#  6   start_station_longitude  object
#  7   end_station_id           object
#  8   end_station_name         object
#  9   end_station_latitude     object
#  10  end_station_longitude    object
#  11  bike_id                  object
#  12  user_type                object
#  13  member_birth_year        object
#  14  member_gender            object
#  15  bike_share_for_all_trip  object
#  16  rental_access_method     object
#  17  ride_id                  object
#  18  rideable_type            object
#  19  started_at               object
#  20  ended_at                 object
#  21  start_lat                object
#  22  start_lng                object
#  23  end_lat                  object
#  24  end_lng                  object
#  25  member_casual            object
# dtypes: object(26)
# memory usage: 1.8+ GB

# %%
# check empty rows in as a % of all data:
100 * df.isnull().sum() / len(df)
# Out:
# duration_sec               36.111927
# start_time                 36.111927
# end_time                   36.111927
# start_station_id           15.526225
# start_station_name         15.506018
# start_station_latitude     36.111927
# start_station_longitude    36.111927
# end_station_id             16.324224
# end_station_name           16.304094
# end_station_latitude       36.111927
# end_station_longitude      36.111927
# bike_id                    36.111927
# user_type                  36.111927
# member_birth_year          71.525248
# member_gender              71.521345
# bike_share_for_all_trip    54.499430
# rental_access_method       91.856684
# ride_id                    63.888073
# rideable_type              63.888073
# started_at                 63.888073
# ended_at                   63.888073
# start_lat                  63.888073
# start_lng                  63.888073
# end_lat                    63.933425
# end_lng                    63.933425
# member_casual              63.888073
# dtype: float64

# %%
df[~df['started_at'].isnull()]
# Out:
#         duration_sec start_time end_time start_station_id  \
# 0                NaN        NaN      NaN              NaN
# 1                NaN        NaN      NaN              NaN
# 2                NaN        NaN      NaN              NaN
# 3                NaN        NaN      NaN              NaN
# 4                NaN        NaN      NaN              NaN
# ...              ...        ...      ...              ...
# 2035158          NaN        NaN      NaN         SF-J22-1
# 2035159          NaN        NaN      NaN         SF-J22-1
# 2035160          NaN        NaN      NaN         SF-J22-1
# 2035161          NaN        NaN      NaN           SF-E27
# 2035162          NaN        NaN      NaN           SF-E27
#
#                      start_station_name start_station_latitude  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
# ...                                 ...                    ...
# 2035158         Octavia Blvd at Page St                    NaN
# 2035159         Octavia Blvd at Page St                    NaN
# 2035160         Octavia Blvd at Page St                    NaN
# 2035161  Commercial St at Montgomery St                    NaN
# 2035162  Commercial St at Montgomery St                    NaN
#
#         start_station_longitude end_station_id      end_station_name  \
# 0                           NaN            NaN                   NaN
# 1                           NaN            NaN                   NaN
# 2                           NaN            NaN                   NaN
# 3                           NaN            NaN                   NaN
# 4                           NaN            NaN                   NaN
# ...                         ...            ...                   ...
# 2035158                     NaN         SF-T20  29th St at Church St
# 2035159                     NaN         SF-T20  29th St at Church St
# 2035160                     NaN         SF-T20  29th St at Church St
# 2035161                     NaN         SF-H28   Folsom St at 3rd St
# 2035162                     NaN         SF-H28   Folsom St at 3rd St
#
#         end_station_latitude  ... rental_access_method           ride_id  \
# 0                        NaN  ...                  NaN  3D9845E1B2804C08
# 1                        NaN  ...                  NaN  F3DB8D3050725894
# 2                        NaN  ...                  NaN  150C11B009DAD946
# 3                        NaN  ...                  NaN  055A3F9E3CFAA764
# 4                        NaN  ...                  NaN  77CB40EC8FEBC219
# ...                      ...  ...                  ...               ...
# 2035158                  NaN  ...                  NaN  2FE203703F61504C
# 2035159                  NaN  ...                  NaN  83A949ACA2F100BA
# 2035160                  NaN  ...                  NaN  DF9AFD9189059588
# 2035161                  NaN  ...                  NaN  AE93E1B2E9817029
# 2035162                  NaN  ...                  NaN  3A9E409AE6AE8D96
#
#          rideable_type           started_at             ended_at  \
# 0        electric_bike  2020-12-26 10:19:34  2020-12-26 10:22:27
# 1        electric_bike  2020-12-06 12:28:33  2020-12-06 12:37:29
# ...                    ...                     ...                      ...
# 1845997                NaN               37.809067              -122.474854
# 1845998                NaN               37.809074              -122.474915
# 1845999                NaN               37.809101              -122.474937
# 1846002                NaN               37.809139              -122.415688
# 1846009                NaN               37.809177              -122.415756
#
#          end_station_id end_station_name  end_station_latitude  \
# 1731850             NaN              NaN             37.294456
# 1731855             NaN              NaN             37.294453
# 1731878             NaN              NaN             37.305733
# 1731889             NaN              NaN             37.291027
# 1731923             NaN              NaN             37.291145
# ...                 ...              ...                   ...
# 1845997             NaN              NaN             37.805210
# 1845998             NaN              NaN             37.805187
# 1845999             NaN              NaN             37.805172
# 1846002             NaN              NaN             37.806194
# 1846009             NaN              NaN             37.806160
#
#          end_station_longitude   bike_id   user_type  member_birth_year  \
# 1731850            -121.852409  967152.0    Customer                NaN
# 1731855            -121.852455  967152.0    Customer                NaN
# 1731878            -121.898979  809335.0    Customer                NaN
# 1731889            -121.849129  967152.0    Customer                NaN
# 1731923            -121.849182  967152.0    Customer                NaN
# ...                        ...       ...         ...                ...
# 1845997            -122.433922  326439.0  Subscriber                NaN
# 1845998            -122.433563  232967.0    Customer                NaN
# 1845999            -122.433601  474460.0    Customer                NaN
# 1846002            -122.405258  866334.0    Customer                NaN
# 1846009            -122.405296  572370.0    Customer                NaN
#
#         member_gender bike_share_for_all_trip rental_access_method ride_id  \
# 1731850           NaN                     NaN              clipper     NaN
# 1731855           NaN                     NaN              clipper     NaN
# 1731878           NaN                     NaN                  app     NaN
# 1731889           NaN                     NaN              clipper     NaN
# 1731923           NaN                     NaN              clipper     NaN
# ...               ...                     ...                  ...     ...
# 1845997           NaN                     NaN                  app     NaN
# 1845998           NaN                     NaN                  app     NaN
# 1845999           NaN                     NaN                  app     NaN
# 1846002           NaN                     NaN                  app     NaN
# 1846009           NaN                     NaN                  app     NaN
#
#         rideable_type
# 1731850           NaN
# 1731855           NaN
# 1731878           NaN
# 1731889           NaN
# 1731923           NaN
# ...               ...
# 1845997           NaN
# 1845998           NaN
# 1845999           NaN
# 1846002           NaN
# 1846009           NaN
#
# [7512 rows x 18 columns]

# %%
df.drop_duplicates(inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [start_time, end_time, start_station_id, start_station_name, start_station_latitude, start_station_longitude, end_station_id, end_station_name, end_station_latitude, end_station_longitude, bike_id, user_type, member_birth_year, member_gender, bike_share_for_all_trip, rental_access_method, ride_id, rideable_type]
# Index: []

# %% [markdown]
# ## 1. Change data types:

# %%
# convert to datetime
col = ['start_time','end_time', 'started_at','ended_at']
for i in col:
    df[i]  = pd.to_datetime(df[i])

# %%
# convert to float
col = ['start_station_latitude', 'start_station_longitude','end_station_latitude','end_station_longitude',
       'start_lat','start_lng','end_lat','end_lng']
for i in col:
    df[i]  = pd.to_numeric(df[i], errors='coerce', downcast='float')

# %%
# convert to int
col = ['bike_id','start_station_id','end_station_id','member_birth_year','duration_sec']
for i in col:
    df[i]  = pd.to_numeric(df[i], errors='coerce', downcast='integer')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9071194 entries, 0 to 2035162
# Data columns (total 26 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   duration_sec             float64
#  1   start_time               datetime64[ns]
#  2   end_time                 datetime64[ns]
#  3   start_station_id         float64
#  4   start_station_name       object
#  5   start_station_latitude   float32
#  6   start_station_longitude  float32
#  7   end_station_id           float64
#  8   end_station_name         object
#  9   end_station_latitude     float32
#  10  end_station_longitude    float32
#  11  bike_id                  float64
#  12  user_type                object
#  13  member_birth_year        float64
#  14  member_gender            object
#  15  bike_share_for_all_trip  object
#  16  rental_access_method     object
#  17  ride_id                  object
#  18  rideable_type            object
#  19  started_at               datetime64[ns]
#  20  ended_at                 datetime64[ns]
#  21  start_lat                float32
#  22  start_lng                float32
#  23  end_lat                  float32
#  24  end_lng                  float32
#  25  member_casual            object
# dtypes: datetime64[ns](4), float32(8), float64(5), object(9)
# memory usage: 1.6+ GB

# %% [markdown]
# ## 1. Missing values:

# %%
#check if we can replace Null values in old columns on new coluns values:

old_col = ['start_time','end_time','start_station_latitude','start_station_longitude','end_station_latitude',
          'end_station_longitude','user_type']
new_col = ['started_at','ended_at','start_lat','start_lng','end_lat',
          'end_lng','member_casual']

for i in range(len(old_col)):
    #check `theory: if new_col were added later instead old_col':
    ch = df[~df[old_col[i]].isnull()&~df[new_col[i]].isnull()].shape[0]
    
    #replace Null if theory is true:
    if ch == 0:
        df[old_col[i]].fillna(df[new_col[i]], inplace=True)
    #or error:
    else:
        print('Check columns: ' + old_col[i] + ', ' + new_col[i])

# %%
# drop columns (repeated):
df.drop(new_col, axis = 1, inplace = True)

# %%
# drop column - duration_sec 	:
df.drop(['duration_sec'], axis = 1, inplace = True)

# %%
# check empty rows in as a % of all data:
100 * df.isnull().sum() / len(df)
# Out:
# start_time                  0.000000
# end_time                    0.000000
# start_station_id           42.492642
# start_station_name         15.506018
# start_station_latitude      0.000000
# start_station_longitude     0.000000
# end_station_id             42.510809
# end_station_name           16.304094
# end_station_latitude        0.045352
# end_station_longitude       0.045352
# bike_id                    36.111927
# user_type                   0.000000
# member_birth_year          71.525248
# member_gender              71.521345
# bike_share_for_all_trip    54.499430
# rental_access_method       91.856684
# ride_id                    63.888073
# rideable_type              63.888073
# dtype: float64

# %% [markdown]
# We can assume that some columns where %of missing value is higher 50% were added later.
# We should keep it for better analysis for the years when they were added

# %% [markdown]
# ## 2. Add new columns

# %%
df['duration_min'] = (test_df['end_time'] - test_df['start_time'])/np.timedelta64(1, 'm')
df['start_year']  = df['start_time'].dt.year

# %% [markdown]
# # check data

# %%
df.shape
# Out:
# (9063682, 20)

# %%
file_name = 'bike.csv'
df.to_csv(file_name) # relative position

# %%
#Final
file_stat = os.stat(file_name)
mb = file_stat.st_size/1024/1024
gb = mb/1024
print(mb) 
print(gb)
# Out:
# 1605.646502494812
# 1.5680141625925899

# %%
#Downloaded files:
file_stat = os.stat('data/')
gb_d = file_stat.st_size/1024/1024/1024
print(gb_d)
# Out:
# 3.2782554626464844e-07

# %%
print('the size of files with data were reduced on ' + str(gb_d - gb))
# Out:
# the size of files with data were reduced on -1.5680138347670436
